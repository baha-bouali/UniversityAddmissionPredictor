# %%
#loading our dataset
import pandas as pd
import numpy as np
df=pd.read_csv("Desktop/Placement_Data_Full_Class.csv")
df.head()
#sl_no(serial number)/ssc_p:SecondaryEducationPercentage/ssc_b:Board of education/hsc_p:Higher Secondary Education percentage
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
for i in range (215):
    df["salary"][i]=df["salary"][i]/10000
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status  salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed    27.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed    20.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed    25.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed     NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed    42.5

# %% [markdown]
# # Data Preprocessing

# %%
df["salary"].fillna(df["salary"].mean(),inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Bar plots

# %%
sns.countplot(x="gender",data=df)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
df["specialisation"].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
values = [120,95]
bars = ("Mkt&Fin", "Mkt&HR")
y_pos = np.arange(len(bars))
plt.barh(y_pos,values)
plt.yticks(y_pos, bars)
plt.title("distribution of specialisation (PostGraduation)")
plt.show()

# %%
df["workex"].value_counts()
# Out:
# No     141
# Yes     74
# Name: workex, dtype: int64

# %%
fig = plt.figure()
values = [141,74]
bars = ("No", "Yes")
patterns = ["*"]
ax = fig.add_subplot(111)
for i in range (len(patterns)):
    ax.bar(bars, values, color='white', edgecolor='red',hatch=patterns[i])
plt.title("work experience")
plt.show()

# %%
sns.countplot(x="status",data=df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %% [markdown]
# # Pie charts

# %%
df["hsc_s"].value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_s, dtype: int64

# %%
labels = 'Commerce', 'Science', 'Arts'
sizes = [113, 91, 11]
colors = ['#ff9999','#ffcc99','#99ff99']
explode = (0, 0, 0) 
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False,startangle=140)
plt.axis('equal')
plt.title("Distribution of Specialization in Higher Secondary Education")
plt.show()

# %%
df["degree_t"].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
labels = ["Comm&Mgmt","Sci&Tech" ,"Others"]
sizes = [145,59,11]
colors = ['#ff9999','#66b3ff','#99ff99',]
explode = (0.07,0.07,0.07)
plt.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')  
plt.tight_layout()
plt.title("Distribution of under gradution fields")
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.title("salary")
plt.xlabel("salary")
df["salary"].plot.hist()

# %% [markdown]
# # Correlation

# %%
new_df=df[["ssc_p","hsc_p","etest_p"]]
sns.boxplot(data=new_df)

# %% [markdown]
# # Density plot

# %%
p1=sns.kdeplot(df['degree_p'], shade=True, color="g")
p1=sns.kdeplot(df['etest_p'], shade=True, color="dodgerblue")
p1=sns.kdeplot(df['hsc_p'], shade=True, color="black")
p1=sns.kdeplot(df['ssc_p'], shade=True, color="deeppink")

# %% [markdown]
# # Scatter plots

# %%
import matplotlib.pyplot as plt
import numpy as np
# use the scatter function
plt.scatter(df.hsc_p,df.ssc_p , alpha=0.5,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# use the scatter function
plt.scatter(df.etest_p,df.degree_p , alpha=0.5,color='olive')
plt.show()

# %% [markdown]
# # preprocessing part 2

# %%
convdf=df.drop('sl_no',axis=1)

# %%
convdf["gender"]=convdf["gender"].map({"M":1,"F":0})

# %%
convertisseur={"workex":{"Yes":1,"No":0}}
convdf.replace(convertisseur,inplace=True)

# %%
convdf["specialisation"]=convdf["specialisation"].map({"Mkt&Fin":0,"Mkt&HR":1})

# %%
convertisseur2={"status":{"Placed":1,"Not Placed":0}}
convdf.replace(convertisseur2,inplace=True)

# %% [markdown]
# # heatmap

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( convdf)

# %%
grid=sns.FacetGrid(convdf,col="status")
grid.map(plt.hist,"degree_p",bins=20)
grid.add_legend()

# %%
grid3=sns.FacetGrid(convdf,row="status",col="workex",size=2.2,aspect=1.6)
grid3.map(sns.barplot,"gender",'etest_p',alpha=.5,ci=None)
grid3.add_legend()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # Prepering our data for Machine Learning

# %%
convdf["hsc_s"].value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_s, dtype: int64

# %%
convdf["degree_t"].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
convdf["hsc_s"]=convdf["hsc_s"].map({"Commerce":0,"Science":1,"Arts":2})
convdf["degree_t"]=convdf["degree_t"].map({"Comm&Mgmt":0,"Sci&Tech":1,"Others":2})

# %%
convdf["ssc_b"]=convdf["ssc_b"].map({"Others":0,"Central":1})

# %%
convdf["hsc_b"]=convdf["hsc_b"].map({"Others":0,"Central":1})

# %%
convdf.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      0  91.00      0      0     58.00         1       0
# 1       1  79.33      1  78.33      0      1     77.48         1       1
# 2       1  65.00      1  68.00      1      2     64.00         0       0
# 3       1  56.00      1  52.00      1      1     52.00         1       0
# 4       1  85.80      1  73.60      1      0     73.30         0       0
#
#    etest_p  specialisation  mba_p  status     salary
# 0     55.0               1  58.80       1  27.000000
# 1     86.5               0  66.28       1  20.000000
# 2     75.0               0  57.80       1  25.000000
# 3     66.0               1  59.43       0  28.865541
# 4     96.8               0  55.50       1  42.500000

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # training and splitting data

# %%
x=convdf.drop(['ssc_b','hsc_b','status','salary','mba_p'],axis=1)
y=convdf['status']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=10)

# %% [markdown]
# # Logistic Regression algorithm

# %%
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
logit_roc_auc = roc_auc_score(y_test, logreg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.05, 0.9])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print("accuracy={:2f}".format(logreg.score(x_test,y_test)))
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accuracy=0.868421

# %% [markdown]
# # decision tree algorithm

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
logit_roc_auc = roc_auc_score(y_test, clf.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, clf.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Decision Tree(area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.05, 0.9])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print("accuracy:{}".format(metrics.accuracy_score(y_test, y_pred)))
# Out:
# accuracy:0.8157894736842105

# %% [markdown]
# # random forest algorithm

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
logit_roc_auc = roc_auc_score(y_test, rf.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, rf.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Random Forest(area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.05, 0.9])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8421052631578947

# %% [markdown]
# # KNN algorithm

# %%
classifier=KNeighborsClassifier(n_neighbors=4)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
logit_roc_auc = roc_auc_score(y_test, classifier.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, classifier.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='KNN(area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.05, 0.9])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
print("accuracy:{}".format(metrics.accuracy_score(y_test, y_pred)))
# Out:
# accuracy:0.7631578947368421

# %% [markdown]
# # Let's plot all the algorithms together

# %%
plt.figure()
models = [
{
    'label': 'Logistic Regression',
    'model': LogisticRegression(),
},
{
    'label': 'Decision Tree',
    'model': DecisionTreeClassifier(),
},
    {
    'label': 'Random Forest',
    'model': RandomForestClassifier(),
},
    {
    'label': 'KNN',
    'model': KNeighborsClassifier(n_neighbors=5),
}
]
for m in models:
    model = m['model'] 
    model.fit(x_train, y_train) 
    y_pred=model.predict(x_test) 
    fpr, tpr, thresholds = metrics.roc_curve(y_test, model.predict_proba(x_test)[:,1])
    auc = metrics.roc_auc_score(y_test,model.predict(x_test))
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['label'], auc))
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.05, 0.9])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
final_model=LogisticRegression()
final_model.fit(x_train,y_train)
y_pred=final_model.predict(x_test)
com={"Actual":y_test,"Predicted":y_pred}
comparaison=pd.DataFrame(com)
comparaison
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#      Actual  Predicted
# 78        1          1
# 91        0          0
# 110       1          1
# 124       1          1
# 70        1          1
# ..      ...        ...
# 98        1          1
# 209       1          1
# 43        1          1
# 166       1          1
# 21        1          1
#
# [76 rows x 2 columns]

# %% [markdown]
# # confusion matrics

# %%
confusion=pd.crosstab(y_test,y_pred)
confusion
# Out:
# col_0    0   1
# status
# 0       17   8
# 1        2  49

# %%
y_pred=1

# %% [markdown]
# # Let's test our model

# %%
gender_input=int(input('enter your gender if M write 1 if F write 0 '))
ssc_p_input=float(input('enter your Secondary Education percentage- 10th Grade '))
hsc_p_input=float(input('enter your Higher Secondary Education percentage- 12th Grade '))
hsc_s_input=int(input('enter your Specialization in Higher Secondary Education 0 for Commerce,1 for Science,2 for Arts '))
# Out:
# enter your gender if M write 1 if F write 0 1
# enter your Secondary Education percentage- 10th Grade 100.00
# enter your Higher Secondary Education percentage- 12th Grade 100.00
# enter your Specialization in Higher Secondary Education 0 for Commerce,1 for Science,2 for Arts 0

# %%
degree_p_input=float(input('enter your Degree Percentage '))
degree_t_input=int(input("Under Graduation(Degree type) 0 for Comm&Mgmt, 1 for Sci&Tech and 2 for Others"))
workex_input=int(input("enter  0 if you don't have a work experience and 1 if you have "))
etest_p_input=float(input("enter your Employability test percentage conducted by college "))
specialisation_input=int(input("enter your specialisation 0 for Mkt&Fin and 1 forMkt&HR "))
df2=pd.DataFrame({"gender":[gender_input],"ssc_p":[ssc_p_input],"hsc_p":[hsc_p_input],"hsc_s_input":[hsc_s_input],"degree_t":[degree_t_input],"degree_p":[degree_p_input],
                  "workex":[workex_input],"etest_p":[etest_p_input],"specialisation":[specialisation_input]})
# Out:
# enter your Degree Percentage 100.00
# Under Graduation(Degree type) 0 for Comm&Mgmt, 1 for Sci&Tech and 2 for Others0
# enter  0 if you don't have a work experience and 1 if you have 1
# enter your Employability test percentage conducted by college 100.00
# enter your specialisation 0 for Mkt&Fin and 1 forMkt&HR 0

# %%
y_pred=final_model.predict(df2)
y_pred_result=int(y_pred)
y_pred_result
# Out:
# 1

# %%
if y_pred_result==1:
    print("Gongrats you're placed") #if the result is 1 the person is probanly placed
    from sklearn.linear_model import LinearRegression
    from sklearn.metrics import mean_squared_error
    from sklearn import metrics 
    X=convdf.drop(['ssc_b','hsc_b','salary','mba_p'],axis=1)
    Y=convdf["salary"]
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=10)
    salarymodel=LinearRegression()
    salarymodel.fit(X_train,Y_train)
    Y_pred=salarymodel.predict(X_test)
     #print("Mean Squared Error is ",mean_squared_error(Y_test,Y_pred))
    status_input=y_pred_result
    df3=pd.DataFrame({"gender":[gender_input],"ssc_p":[ssc_p_input],"hsc_p":[hsc_p_input],"hsc_s_input":[hsc_s_input],"degree_t":[degree_t_input],"degree_p":[degree_p_input],
                  "workex":[workex_input],"etest_p":[etest_p_input],"specialisation":[specialisation_input],"status":[status_input]})
    Y_pred=salarymodel.predict(df3)
    Y_pred_result=int(Y_pred)
    print("And your salary will be about ",Y_pred_result) 
else:
    print("So sorry you're not placed") #if the result is 0 the person probably is not placed
# Out:
# Gongrats you're placed
# And your salary will be about  276

# %% [markdown]
# # Thank you for your attention we wish you enjoyed it !!!
